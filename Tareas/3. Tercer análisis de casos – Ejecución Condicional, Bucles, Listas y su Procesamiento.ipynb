# %% [markdown]
# # Tarea Semana 07: Tercer Análisis de Casos
# ## Ejecución Condicional, Bucles, Listas y su Procesamiento
#
# **Valor:** 5%
# **Curso:** Fundamentos de Python
# **Nombre del estudiante:** Yislein Madrigal Ramírez
# **Fecha:** Jueves 9 de julio 2026
#
# ### Objetivo general
# Resolver casos de análisis de datos aplicando ejecución condicional, ciclos de programación, listas, funciones simples y estructuras de datos básicas.
#
# ### Objetivos específicos
#
# 1. Analizar la utilización de la ejecución condicional de los algoritmos para el análisis de datos.
# 2. Analizar el comportamiento de los ciclos de programación en el diseño de algoritmos.
# 3. Integrar aprendizajes de las semanas 1 a 7: análisis del problema, entrada-proceso-salida, variables, condicionales, validación, indicadores, listas, ciclos, diccionarios simples y funciones.
#
# ### Contexto
# Esta tarea simula pequeñas situaciones de análisis de datos en Costa Rica. No se evalúa solo que el código funcione: también se evalúa que el estudiante pueda explicar el problema, elegir estructuras adecuadas, probar casos y justificar resultados.

# %% [markdown]
# ## Formato obligatorio para cada caso
#
# Complete las siguientes partes antes de escribir el código:
#
# 1. **Problema:** describa qué debe resolver el programa.
# 2. **Entrada / datos:** indique qué datos usa el algoritmo.
# 3. **Proceso:** explique qué cálculos, condiciones o ciclos se aplican.
# 4. **Salida esperada:** describa qué reporte o mensaje debe mostrar.
# 5. **Código:** escriba y ejecute la solución.
# 6. **Pruebas:** documente tres escenarios:
#    - caso normal;
#    - caso límite;
#    - caso inválido o situación especial.
#
# ### Reglas técnicas
#
# - Use nombres de variables descriptivos en `snake_case`.
# - Use `for` en los casos donde deba recorrer listas.
# - Use `if`, `elif` y `else` para clasificar resultados.
# - Use funciones simples cuando un cálculo se repita.
# - Use `try-except` cuando solicite datos numéricos al usuario.
# - No use Pandas, archivos externos, API real ni librerías no vistas en clase.
# - Puede usar `set` y tuplas solo como extensión breve cuando el caso lo indique.

# %% [markdown]
# ## Rúbrica de evaluación - 5%
#
# | Criterio | Valor |
# |---|---:|
# | Análisis del problema, entrada-proceso-salida y pruebas manuales | 1.0% |
# | Uso correcto de condicionales para clasificar o decidir | 1.0% |
# | Uso correcto de ciclos y listas para procesar varios datos | 1.0% |
# | Uso de funciones simples y estructuras adecuadas | 1.0% |
# | Claridad del reporte, interpretación y reflexión final | 1.0% |
#
# ### Penalizaciones posibles
#
# - Código que no ejecuta por errores de sintaxis: hasta -1.0%.
# - Variables con nombres ambiguos como `x`, `a`, `dato1`: hasta -0.5%.
# - No documentar pruebas: hasta -1.0%.
# - Copiar una solución sin explicación propia: según criterio docente.

# %% [markdown]
# ## Casos obligatorios
#
# | # | Caso | Descripción | Habilidades clave |
# |---|---|---|---|
# | 1 | Control de ventas diarias | Analiza ventas de una soda costarricense durante 5 días. | listas, `sum`, promedio, `if/elif/else` |
# | 2 | Asistencia a actividad cultural | Recorre asistencias y clasifica ocupación según capacidad. | ciclos, contadores, porcentajes |
# | 3 | Precios de feria | Procesa precios de productos y detecta valores altos o bajos. | listas, máximo, mínimo, rango, condiciones |
# | 4 | Reto integrador: Red EmprendeCR | Integra semanas 1 a 7 con lista de diccionarios, funciones, ciclos y reporte final. | funciones, listas, diccionarios, ciclos, condicionales |

# %% [markdown]
# ---
# # Caso 1: Control de ventas diarias de una soda
#
# ## Problema
# Una soda ubicada en San Pedro registra sus ventas de lunes a viernes. El programa debe calcular el total semanal, el promedio diario y clasificar el resultado según una meta.
#
# ## Entrada / datos
# Use esta lista base:
#
# ```python
# ventas_soda = [85000, 92000, 78000, 110000, 97000]
# meta_semanal = 450000
# ```
#
# ## Proceso esperado
#
# - Calcular total semanal.
# - Calcular promedio diario.
# - Comparar el total con la meta.
# - Clasificar:
#   - `Meta alcanzada` si el total es mayor o igual a la meta.
#   - `Cerca de la meta` si el total alcanza al menos el 80% de la meta.
#   - `Requiere atención` si no alcanza el 80%.
#
# ## Salida esperada
# Debe mostrar total, promedio, porcentaje de cumplimiento y estado final.
#
# ## Pruebas manuales
#
# | Escenario | Datos de entrada | Resultado esperado | Resultado obtenido |
# |---|---|---|---|
# | Caso normal | `[85000, 92000, 78000, 110000, 97000]`, meta `450000` | Meta alcanzada | Meta alcanzada |
# | Caso límite | total exactamente igual a la meta | Meta alcanzada | Meta alcanzada |
# | Caso especial | total menor al 80% de la meta | Requiere atención | Requiere atención |

# %%
# Caso 1 - Escriba su solución aquí

ventas_soda = [85000, 92000, 78000, 110000, 97000]
meta_semanal = 450000

def calcular_total(lista_ventas):
    return sum(lista_ventas)

def calcular_promedio(lista_ventas):
    return sum(lista_ventas) / len(lista_ventas)

def calcular_porcentaje(total_ventas,meta):
    return total_ventas / meta * 100

def calcular_clasificacion(porcentaje_logro):
    if porcentaje_logro >= 100:
        clasificacion_emprendimiento = "Meta alcanzada, emprendimiento rentable"
    elif porcentaje_logro >= 80:
        clasificacion_emprendimiento = "Observación, no se logró la meta"
    else:
        clasificacion_emprendimiento = "ADVERTENCIA, problemas de rentabilidad. URGE ATENCION"
    return clasificacion_emprendimiento

# Complete el análisis

# 1. Calculamos el total usando la función que creaste arriba
total_soda = calcular_total(ventas_soda)
print("Prueba - Total de la soda:", total_soda)

# 2. Calculamos el promedio diario
promedio_soda = calcular_promedio(ventas_soda)
print("Prueba - Promedio diario:", promedio_soda)

# 3. Calculamos el porcentaje usando el total y la meta
porcentaje_soda = calcular_porcentaje(total_soda, meta_semanal)
print("Prueba - Porcentaje alcanzado:", porcentaje_soda)

# 4. Evaluamos la clasificación según el porcentaje
estado_soda = calcular_clasificacion(porcentaje_soda)
print("Prueba - Estado final:", estado_soda)
# Out:
# Prueba - Total de la soda: 462000
# Prueba - Promedio diario: 92400.0
# Prueba - Porcentaje alcanzado: 102.66666666666666
# Prueba - Estado final: Meta alcanzada, emprendimiento rentable

# %% [markdown]
# ---
# # Caso 2: Asistencia a una actividad cultural
#
# ## Problema
# Una actividad cultural en Costa Rica registra asistencia por bloques horarios. El programa debe calcular la asistencia promedio y clasificar el nivel de ocupación.
#
# ## Entrada / datos
# Use esta lista base:
#
# ```python
# asistencias = [120, 180, 210, 250, 230]
# capacidad = 300
# ```
#
# ## Proceso esperado
#
# - Recorrer la lista con un ciclo `for`.
# - Calcular asistencia total y promedio.
# - Contar cuántos bloques superaron el 70% de capacidad.
# - Clasificar el promedio de ocupación:
#   - `Alta ocupación` si el promedio es mayor o igual al 80% de la capacidad.
#   - `Ocupación media` si el promedio es mayor o igual al 50%.
#   - `Baja ocupación` si el promedio es menor al 50%.
#
# ## Salida esperada
# Debe mostrar total de asistentes, promedio, bloques sobre 70% y estado de ocupación.
#
# ## Pruebas manuales
#
# | Escenario | Datos de entrada | Resultado esperado | Resultado obtenido |
# |---|---|---|---|
# | Caso normal | `[120, 180, 210, 250, 230]`, capacidad `300` | Ocupación media o alta según cálculo | Ocupación media|
# | Caso límite | promedio exactamente 80% de capacidad | Alta ocupación | Alta ocupación|
# | Caso especial | lista con asistencias muy bajas | Baja ocupación |Baja ocupación|

# %%
# Caso 2 - Escriba su solución aquí

asistencias = [120, 180, 210, 250, 230]
capacidad = 300

# Complete el análisis

total_asistencias = 0
bloques_sobre_70 = 0

for cantidad in asistencias:
    total_asistencias = total_asistencias + cantidad
    if cantidad > 70:
        bloques_sobre_70 = bloques_sobre_70 + 1


promedio_asistencia = total_asistencias / capacidad
porcentaje_ocupacion = (promedio_asistencia / capacidad) * 100

if porcentaje_ocupacion >= 80:
    estado = "Alta ocupación"
elif porcentaje_ocupacion >= 50:
    estado = "Ocupación media"
else:
    estado = "Baja ocupación"

print("Total de asistentes:", total_asistencias)
print("Promedio de asistencia:", promedio_asistencia)
print("Bloques que superaron el 70%:", bloques_sobre_70)
print("Estado de ocupación:", estado)
# Out:
# Total de asistentes: 990
# Promedio de asistencia: 3.3
# Bloques que superaron el 70%: 5
# Estado de ocupación: Baja ocupación

# %% [markdown]
# ---
# # Caso 3: Precios de productos de feria
#
# ## Problema
# Una persona compara precios de un mismo producto en diferentes ferias del agricultor. El programa debe analizar los precios y detectar si hay mucha variación.
#
# ## Entrada / datos
# Use esta lista base:
#
# ```python
# producto = "Tomate"
# precios = [900, 850, 1000, 950, 1200]
# ```
#
# ## Proceso esperado
#
# - Calcular precio promedio.
# - Identificar precio mínimo y máximo.
# - Calcular rango de precios: `máximo - mínimo`.
# - Clasificar la variación:
#   - `Variación alta` si el rango es mayor o igual a 300.
#   - `Variación moderada` si el rango es mayor o igual a 150.
#   - `Variación baja` si el rango es menor a 150.
# - Usar un ciclo para contar cuántos precios están por encima del promedio.
#
# ## Salida esperada
# Debe mostrar producto, promedio, mínimo, máximo, rango, precios sobre promedio y clasificación.
#
# ## Pruebas manuales
#
# | Escenario | Datos de entrada | Resultado esperado | Resultado obtenido |
# |---|---|---|---|
# | Caso normal | `[900, 850, 1000, 950, 1200]` | Variación alta | Variación alta |
# | Caso límite | rango exactamente `300` | Variación alta | Variación alta|
# | Caso especial | todos los precios iguales | Variación baja | Variación baja|

# %%
# Caso 3 - Escriba su solución aquí

producto = "Tomate"
precios = [900, 850, 1000, 950, 1200]

# Complete el análisis

promedio_precio = sum(precios) / len(precios)
precio_minimo = min(precios)
precio_maximo = max(precios)

rango = precio_maximo - precio_minimo

if rango >= 300:
    clasificacion = "Variación alta"
elif rango >= 150:
    clasificacion = "Variación moderada"
else:
    clasificacion = "Variación baja"

precios_sobre_promedio = 0

for precio in precios:
    if precio < promedio_precio:
        precios_sobre_promedio = precios_sobre_promedio + 1

print("Producto:", producto)
print("Promedio:", promedio_precio)
print("Precio mínimo:", precio_minimo)
print("Precio máximo:", precio_maximo)
print("Rango de precios:", rango)
print("Precios sobre el promedio:", precios_sobre_promedio)
print("Clasificación de variación:", clasificacion)
# Out:
# Producto: Tomate
# Promedio: 980.0
# Precio mínimo: 850
# Precio máximo: 1200
# Rango de precios: 350
# Precios sobre el promedio: 3
# Clasificación de variación: Variación alta

# %% [markdown]
# ---
# # Caso 4: Reto integrador - Red EmprendeCR
#
# ## Problema
# Una red de emprendimientos costarricenses desea analizar el desempeño semanal de varias sedes. Cada sede tiene nombre, provincia, tipo de negocio, ventas diarias y meta semanal.
#
# Este reto integra aprendizajes de las semanas 1 a 7:
#
# - Semana 1: comprensión del problema y algoritmo.
# - Semana 2: variables y entrada-proceso-salida.
# - Semana 3: decisiones con condicionales.
# - Semana 4: validación y código limpio.
# - Semana 5: indicadores para análisis de datos.
# - Semana 6: listas y ciclos.
# - Semana 7: listas de diccionarios, funciones y elección de estructuras.
#
# ## Datos base
#
# Use esta lista de diccionarios:
#
# ```python
# sedes = [
#     {
#         "nombre": "Soda San Pedro",
#         "provincia": "San José",
#         "tipo": "Alimentación",
#         "ventas": [85000, 92000, 78000, 110000, 97000],
#         "meta": 450000,
#     },
#     {
#         "nombre": "Panadería Cartago",
#         "provincia": "Cartago",
#         "tipo": "Panadería",
#         "ventas": [65000, 70000, 72000, 69000, 75000],
#         "meta": 380000,
#     },
#     {
#         "nombre": "Cafetería Liberia",
#         "provincia": "Guanacaste",
#         "tipo": "Cafetería",
#         "ventas": [98000, 105000, 99000, 120000, 115000],
#         "meta": 500000,
#     },
# ]
# ```
#
# ## Requisitos mínimos
#
# 1. Crear una función `calcular_total(ventas)`.
# 2. Crear una función `calcular_promedio(ventas)`.
# 3. Crear una función `clasificar_sede(total, meta)`.
# 4. Recorrer todas las sedes con un ciclo `for`.
# 5. Imprimir un reporte por sede con:
#    - nombre;
#    - provincia;
#    - total semanal;
#    - promedio diario;
#    - porcentaje de cumplimiento;
#    - estado.
# 6. Crear un `set` con las provincias presentes.
# 7. Crear una lista de tuplas `(nombre, total)` para guardar el ranking base.
# 8. Identificar la sede con mayor venta total.
#
# ## Clasificación requerida
#
# - `Meta alcanzada`: total mayor o igual a la meta.
# - `Cerca de la meta`: total mayor o igual al 80% de la meta.
# - `Requiere atención`: total menor al 80% de la meta.
#
# ## Salida esperada
# El reporte debe ser claro y comprensible para una persona que no está viendo el código.
#
# ## Pruebas manuales
#
# | Escenario | Datos de entrada | Resultado esperado | Resultado obtenido |
# |---|---|---|---|
# | Caso normal | datos base | Reporte para las 3 sedes | Reporte para las 3 sedes|
# | Caso límite | una sede con total igual a la meta | Meta alcanzada | Meta alcanzada |
# | Caso especial | una sede con ventas muy bajas | Requiere atención | Requiere atención |

# %%
# Caso 4 - Reto integrador

sedes = [
    {
        "nombre": "Soda San Pedro",
        "provincia": "San José",
        "tipo": "Alimentación",
        "ventas": [85000, 92000, 78000, 110000, 97000],
        "meta": 450000,
    },
    {
        "nombre": "Panadería Cartago",
        "provincia": "Cartago",
        "tipo": "Panadería",
        "ventas": [65000, 70000, 72000, 69000, 75000],
        "meta": 380000,
    },
    {
        "nombre": "Cafetería Liberia",
        "provincia": "Guanacaste",
        "tipo": "Cafetería",
        "ventas": [98000, 105000, 99000, 120000, 115000],
        "meta": 500000,
    },
]

provincias  = set()
ranking = []
max_venta =0
mejor_sede = " "

# 1. Defina las funciones
def calcular_total(ventas):
    return sum(ventas)

def calcular_promedio(ventas):
    return sum(ventas)/len(ventas)

def clasificar_sede(total, meta):
    porcentaje = (meta/total)*100
    
    if total >= meta:
        return "Meta alcanzada"
    elif porcentaje >= meta:
        return "Cerca de la meta"
    else:
        return "Requiere atención"
    
# 2. Recorra las sedes y genere el reporte
print("------REPORTE DE SEDES-----")

for sede in sedes:
    nombre = sede["nombre"]
    provincia = sede["provincia"]
    ventas = sede["ventas"]
    meta = sede["meta"]
    
    total = calcular_total(ventas)
    promedio = calcular_promedio(ventas)
    estado = clasificar_sede(total, meta)
    porcentaje_real = (total / meta) * 100
    
    provincias.add(provincia)
    ranking.append((nombre, total))
    
    if total > max_venta:
        max_venta = total
        mejor_sede = nombre


# 3. Muestre provincias presentes, ranking base y mejor sede
print(f"\nSede: {nombre}")
print(f"Provincia: {provincia}")
print(f"Total semanal: ₡{total:,.2f}")
print(f"Promedio diario: ₡{promedio:,.2f}")
print(f"Cumplimiento: {porcentaje_real:.2f}%")
print(f"Estado: {estado}")
    
print(f"\nSede: {nombre}")
print("\n--- RESUMEN FINAL ---")
print("Provincias presentes:", provincias)
print("Ranking base:", ranking)
print(f"Mejor sede: {mejor_sede} con un total de ₡{max_venta:,.2f}")
# Out:
# ------REPORTE DE SEDES-----
#
# Sede: Cafetería Liberia
# Provincia: Guanacaste
# Total semanal: ₡537,000.00
# Promedio diario: ₡107,400.00
# Cumplimiento: 107.40%
# Estado: Meta alcanzada
#
# Sede: Cafetería Liberia
#
# --- RESUMEN FINAL ---
# Provincias presentes: {'Cartago', 'San José', 'Guanacaste'}
# Ranking base: [('Soda San Pedro', 462000), ('Panadería Cartago', 351000), ('Cafetería Liberia', 537000)]
# Mejor sede: Cafetería Liberia con un total de ₡537,000.00

# %% [markdown]
# ---
# # Reflexión final
#
# Responda con sus propias palabras:
#
# 1. ¿Cuál caso le exigió pensar mejor la condición `if/elif/else`? En el Caso 4 tuve que analizar con mucho cuidado cómo calcular matemáticamente el porcentaje correcto (dividiendo el total entre la meta) para que el if y el elif pudieran clasificar bien si la sede alcanzó la meta o si estaba cerca. También en el Caso 3 tuve que pensar bien en la lógica, ya que si restaba los valores al revés para sacar el rango de precios, me daba un número negativo y las condiciones del if iban a fallar por completo.
#
# 2. ¿Para qué sirvió usar ciclos en lugar de repetir código manualmente? Me sirvió para ahorrar tiempo, hacer el código más corto y evitar errores. Sin el ciclo for, habría tenido que escribir las mismas fórmulas para calcular totales, promedios y clasificaciones una por una, para cada sede o para cada día de la semana. Con el ciclo, le doy la instrucción una sola vez y el programa se encarga de recorrer toda la lista automáticamente haciendo el trabajo pesado.
#
# 3. ¿Por qué el reto integrador usa una lista de diccionarios? Porque era la forma más lógica y ordenada de agrupar información compleja. La lista principal me permite tener todas las sedes juntas en un solo lugar para poder recorrerlas con un ciclo. Por otro lado, usar un diccionario para cada sede me permite ponerle una "etiqueta" a cada dato específico. Si solo usara listas normales, sería un enredo saber qué dato corresponde a la meta y cuál a la provincia, pero con el diccionario todo queda claramente identificado.
#
# 4. ¿Qué diferencia encontró entre lista, diccionario, tupla y set?
# La lista es ideal para guardar varios datos seguidos que quiero recorrer o que podrían cambiar (como la lista de ventas diarias).
# El diccionario es perfecto para guardar registros usando llaves o etiquetas. Así puedo llamar a sede["nombre"] y obtener exactamente lo que busco sin importar el orden.
# La tupla es como una lista, pero es "fija" y no se puede modificar. Me fue súper útil en el ranking para "amarrar" el nombre de la sede con su venta total de forma segura.
# El set es una colección donde no se permiten elementos repetidos. Fue la herramienta perfecta para extraer las provincias, ya que si analizaba varias sedes de una misma provincia, el set se encargaba de guardarla una sola vez automáticamente.
#
# 5. ¿Qué aprendió de las semanas 1 a 7 que pudo aplicar en esta tarea? Logré ver cómo todos los temas se conectan para formar un programa real. Aprendí a crear variables y hacer cálculos matemáticos básicos (entradas y salidas). Luego le sumamos la capacidad de tomar decisiones con los if/else. Después aprendimos a manejar muchas cantidades de datos usando listas y ciclos for. En esta tarea final, logré aplicar todo eso junto, metiendo mi lógica matemática dentro de funciones para tener un código limpio y utilizando estructuras avanzadas para analizar datos. Además, puse en práctica el "debugging", aprendiendo a leer los errores de Python para corregir mi propia lógica paso a paso.
#
# ## Confirmación de entrega
#
# Antes de entregar, marque:
#
# - [x] Completé los cuatro casos.
# - [x] Ejecuté todas las celdas sin errores de sintaxis.
# - [x] Documenté pruebas manuales.
# - [x] Usé nombres de variables descriptivos.
# - [x] Escribí la reflexión final.
